# %%
seq = [1, 2, 3, 4, 5]

# %%
for num in seq:
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i < 5:
     print("i is: {}".format(i))
     i = i + 1
# Out:
# i is: 1
# i is: 2
# i is: 3
# i is: 4

# %%
list (range(2, 10))
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9]

# %%
x = [1, 2, 3, 4]
out = []

for num in x:
    out.append(num**2)

# %%
print (out)
# Out:
# [1, 4, 9, 16]

# %%
out = [num**2 for num in x]

# %%
out
# Out:
# [1, 4, 9, 16]

# %%
def my_func (param1):
    print(param1)

# %%
my_func("hello")
# Out:
# hello

# %%
def square(num):
    """
    THIS IS A DOCSTRING.
    CAN GO MULTIPLE LINES.
    THIS FUNCTION SQUARES A NUMBER.
    """

    return num**2

# %%
output = square(2)

# %%
output
# Out:
# 4
