# %%
name = "yigit"
student_num = 10

# %%
print("My number is: {}, and my name is: {}".format(student_num,name))
# Out:
# My number is: 10, and my name is: yigit

# %%
print("My number is: {one}, and my name is: {two}, my number again: {one}.".format(one = student_num, two = name))
# Out:
# My number is: 10, and my name is: yigit, my number again: 10.

# %%
nest = [1, 2, [3, 4]]

# %%
nest[2][1]
# Out:
# 4

# %%
nest = [1, 2, 3, [4, 5, ['target']]]

# %%
print(nest[3][2][0])
# Out:
# target
