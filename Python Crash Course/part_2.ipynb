# %%
d = {"key1": "value", "key2": 123}

# %%
d["key1"]
# Out:
# 'value'

# %%
 d["key2"]
# Out:
# 123

# %%
d = {"key": [1,2,3]}

# %%
d["key"][2]
# Out:
# 3

# %%
d = {"key": {"innerkey": [1,2,3]}}

# %%
d["key"]["innerkey"][2]
# Out:
# 3

# %%
if 1 < 2: 
    print("yess!")
# Out:
# yess!

# %%
if 10 > 7: 
    print("Messi")
elif 10 == 10:
    print("Leo")
else 1
# Out:
# Messi
